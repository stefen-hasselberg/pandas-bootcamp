# %%
import pandas as pd

# %%
data_url = "./data/nutrition.csv"
nutrition = pd.read_csv(data_url, index_col=[0])

# %%
nutrition.head(10)
# Out:
#                  name serving_size  calories total_fat saturated_fat  \
# 0          Cornstarch        100 g       381      0.1g           NaN
# 1        Nuts, pecans        100 g       691       72g          6.2g
# 2       Eggplant, raw        100 g        25      0.2g           NaN
# 3      Teff, uncooked        100 g       367      2.4g          0.4g
# 4     Sherbet, orange        100 g       144        2g          1.2g
# 5    Cauliflower, raw        100 g        25      0.3g          0.1g
# 6    Taro leaves, raw        100 g        42      0.7g          0.2g
# 7   Lamb, raw, ground        100 g       282       23g           10g
# 8   Cheese, camembert        100 g       300       24g           15g
# 9  Vegetarian fillets        100 g       290       18g          2.8g
#
#   cholesterol     sodium  choline      folate folic_acid  ...      fat  \
# 0           0    9.00 mg   0.4 mg    0.00 mcg   0.00 mcg  ...   0.05 g
# ...

# %%
nutrition.info(memory_usage='deep')

# %%
nutrition.head(10)
# Out:
#                  name serving_size  calories total_fat saturated_fat  \
# 0          Cornstarch        100 g       381      0.1g           NaN
# 1        Nuts, pecans        100 g       691       72g          6.2g
# 2       Eggplant, raw        100 g        25      0.2g           NaN
# 3      Teff, uncooked        100 g       367      2.4g          0.4g
# 4     Sherbet, orange        100 g       144        2g          1.2g
# 5    Cauliflower, raw        100 g        25      0.3g          0.1g
# 6    Taro leaves, raw        100 g        42      0.7g          0.2g
# 7   Lamb, raw, ground        100 g       282       23g           10g
# 8   Cheese, camembert        100 g       300       24g           15g
# 9  Vegetarian fillets        100 g       290       18g          2.8g
#
#   cholesterol     sodium  choline      folate folic_acid  ...      fat  \
# 0           0    9.00 mg   0.4 mg    0.00 mcg   0.00 mcg  ...   0.05 g
# ...

# %% [markdown]
# ### Sample method

# %%
# sample method
# return back a random rows
nutrition.sample(n=10, random_state=12)
# Out:
#                                                    name serving_size  \
# 3713    Thuringer, pork, beef, summer sausage, cervelat        100 g
# 6705  Milk, without added vitamin A and vitamin D, i...        100 g
# 1694                   Babyfood, apple and peach, juice        100 g
# 4257  Blueberries, solids and liquids, heavy syrup, ...        100 g
# 2823       Rice, uncooked, enriched, short-grain, white        100 g
# 8321  Beef, grilled, cooked, all grades, trimmed to ...        100 g
# 7229  Child formula, not reconstituted, powder, with...        100 g
# 3438   PEPPERIDGE FARM, 100% Whole Wheat Hamburger Buns        100 g
# 6068  Beef macaroni with tomato sauce, reduced fat, ...        100 g
# 6516  Cowpeas, with salt, drained, boiled, cooked, y...        100 g
#
#       calories total_fat saturated_fat cholesterol      sodium   choline  \
# 3713       362       30g           12g        74mg  1300.00 mg   78.9 mg
# ...

# %%
# to get a randowm percentage of rows
nutrition.sample(frac=0.20)
# Out:
#                                                    name serving_size  \
# 1827                    Alcoholic beverage, light, wine        100 g
# 757                       Quail, raw, meat only, breast        100 g
# 2842       Babyfood, junior, apple and raspberry, fruit        100 g
# 8759  Beef, grilled, cooked, select, trimmed to 0" f...        100 g
# 3008        LITTLE CAESARS 14" Cheese Pizza, Thin Crust        100 g
# ...                                                 ...          ...
# 6194  Veal, braised, cooked, separable lean and fat,...        100 g
# 1977                     Chili, canned entree, no beans        100 g
# 3736    Noodles, with added salt, enriched, cooked, egg        100 g
# 2338             Keikitos (muffins), Latino bakery item        100 g
# 292                                  Seaweed, raw, agar        100 g
#
#       calories total_fat saturated_fat cholesterol     sodium  choline  \
# ...

# %% [markdown]
# ### Bonus - Sampling With Replacement or Weights

# %%
nutrition.sample(n=3, replace=True)
# Out:
#                                                    name serving_size  \
# 5568  Infant Formula, powder, Newborn, Premium, ENFA...        100 g
# 2965        Babyfood, strained, banana pudding, dessert        100 g
# 5023  Soymilk, vitamins A and D, with added calcium,...        100 g
#
#       calories total_fat saturated_fat cholesterol     sodium   choline  \
# 5568       514       27g          7.8g           0  138.00 mg  123.0 mg
# 2965        68      0.8g          0.3g        29mg   54.00 mg   10.7 mg
# 5023        63      1.5g          0.2g           0   53.00 mg   23.6 mg
#
#          folate folic_acid  ...      fat saturated_fatty_acids  \
# 5568  82.00 mcg  82.00 mcg  ...  27.00 g               7.787 g
# 2965   6.00 mcg   0.00 mcg  ...   0.80 g               0.264 g
# 5023  11.00 mcg   0.00 mcg  ...   1.53 g               0.240 g
#
#      monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 5568                     6.968 g                     3.586 g
# ...
